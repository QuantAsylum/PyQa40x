# %%
run PyQa40x_libtest.py
# Out:
# ===== ACQUISITION PARAMETERS =====
# Sample Rate      : 48000 Hz        Max Input Level  : 0 dBV           Max Output Level : 18 dBV
# Pre Buffer       : 2048            Post Buffer      : 2048            FFT Size         : 4096
# Window Type      : hamming
#
# _add_sine_wave: adjusted freq to 996.09375
# _add_sine_wave: adjusted freq to 2003.90625
# Energy 20k Left: 0.02 dBV  Right: -116.80 dBV
